# %% [markdown]
# <a href="https://colab.research.google.com/github/pakizahassan/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/pakizahassan/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
# ## My Lane
#
# I chose **Refresh / Content Opportunity Scoring** as my provisional lane. I selected this lane because it focuses on identifying webpages that may need content updates to improve their search performance. This problem has practical value because website owners cannot manually review every page, so a data-driven approach can help prioritize which pages should be refreshed first. I also chose this lane because it builds on the concepts explored in the starter notebooks and provides a clear business decision that can be supported using machine learning.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
# ## The Question
#
# **Research Question:**
# Which webpages should be prioritized for content updates to improve their search performance?
#
# **Decision:**
# Decide which pages should be refreshed first instead of reviewing every page manually.
#
# **Who takes the action?**
# An SEO specialist or website content manager reviews the recommended pages and updates their content.
#
# **Action:**
# Refresh or improve the selected pages by updating the content, adding new information, improving keywords, or fixing outdated sections.
#
# **Cost of a wrong recommendation:**
# If the model recommends the wrong pages, time and effort may be spent updating pages that do not need changes, while important pages that actually need updates may be ignored. This can reduce the effectiveness of SEO efforts and miss opportunities to improve search performance.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# !git clone https://github.com/pakizahassan/flyrank-ml-internship.git
# %cd flyrank-ml-internship
# Out:
# Cloning into 'flyrank-ml-internship'...
# remote: Enumerating objects: 123, done.
# remote: Counting objects: 100% (123/123), done.
# remote: Compressing objects: 100% (80/80), done.
# remote: Total 123 (delta 37), reused 94 (delta 27), pack-reused 0 (from 0)
# Receiving objects: 100% (123/123), 1.85 MiB | 7.44 MiB/s, done.
# Resolving deltas: 100% (37/37), done.
# /content/flyrank-ml-internship/flyrank-ml-internship

# %%
import os
print(os.listdir("."))
# Out:
# ['AGENTS.md', 'GUIDE.md', 'CLAUDE.md', 'requirements.txt', 'data', '.gitignore', 'DATA_USE.md', 'outputs', 'LICENSE', 'SETUP.md', 'README.md', 'scripts', 'work', 'submission', '.github', 'notebooks', '.git', 'docs', 'skills']

# %%
import os

for root, dirs, files in os.walk("data"):
    for file in files:
        if file.endswith(".csv"):
            print(os.path.join(root, file))
# Out:
# data/raw/content_refresh_anonymized.csv

# %%
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")
print(df.shape[0], "rows,", df.shape[1], "columns")
# Out:
# 30000 rows, 44 columns

# %%
import pandas as pd

# Load the starter dataset
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

# Basic statistics
total_pages = len(df)
avg_ctr = df["ctr"].mean()
avg_position = df["avg_position"].mean()

print(f"Total pages: {total_pages}")
print(f"Average CTR: {avg_ctr:.2f}")
print(f"Average Position: {avg_position:.2f}")
# Out:
# Total pages: 30000
# Average CTR: 0.51
# Average Position: 16.34

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
# ## Careful Words
#
# This project is intended to support decision-making by identifying webpages that may be good candidates for content refresh based on patterns in the available data. The results should be treated as recommendations to help prioritize work, not as guaranteed outcomes.
#
# This project cannot prove that updating a page will improve its ranking or traffic, and it does not predict Google's search algorithm. Many factors influence search performance, so the model provides decision support rather than causal proof.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
